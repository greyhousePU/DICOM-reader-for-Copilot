# %%
# Imports and helpers

import os
import json
import pydicom
from pydicom.dataset import Dataset
from pydicom.datadict import keyword_for_tag, dictionary_description

def to_jsonable(value, trim_long=True, max_len=500):
    """Convert DICOM values to JSON-safe types; trim long strings; handle bytes."""
    if isinstance(value, bytes):
        return f"<{len(value)} bytes>"
    s = str(value)
    if trim_long and len(s) > max_len:
        return s[:max_len] + "...(truncated)"
    return s

def safe_keyword(tag) -> str:
    try:
        return keyword_for_tag(tag) or ""
    except Exception:
        return ""

def safe_description(tag) -> str:
    try:
        return dictionary_description(tag) or ""
    except Exception:
        return ""  # or "Unknown"

def element_header(elem):
    tag = elem.tag
    return {
        "tag": f"({tag.group:04X},{tag.element:04X})",
        "keyword": safe_keyword(tag),
        "name": safe_description(tag),
        "vr": elem.VR,
    }

def dataset_to_dict(ds, depth=0, max_depth=20):
    """
    Recursively serialize a Dataset, preserving tag, keyword, name, VR, and values.
    Skips PixelData (7FE0,0010). Tolerates unknown/private tags.
    """
    if depth > max_depth:
        return {"_note": f"Max depth {max_depth} reached"}

    out = []
    for elem in ds:
        # Skip Pixel Data
        if elem.tag.group == 0x7FE0:
            continue

        entry = element_header(elem)

        if elem.VR == "SQ":
            items = []
            for item in (elem.value or []):
                if isinstance(item, Dataset):
                    items.append(dataset_to_dict(item, depth + 1, max_depth))
                else:
                    items.append(to_jsonable(item))
            entry["value"] = items
        else:
            val = elem.value
            if isinstance(val, (list, tuple)):
                entry["value"] = [to_jsonable(v) for v in val]
            else:
                entry["value"] = to_jsonable(val)

        out.append(entry)
    return out

print("pydicom version:", pydicom.__version__)
# Out:
# pydicom version: 3.0.1

# %%
# Choose the DICOM file to convert

# 🔧 Update this line to pick the file you want to convert:
dicom_path = "/workspaces/DICOM-reader-for-Copilot/DCMRT_Plan(VC04 RESIDENT).dcm"   # e.g., "dicoms/RP1234.dcm" or "RTDOSE.dcm"

# Sanity check: list files in the current folder and verify path exists
print("Current working dir:", os.getcwd())
print("Top-level files:", os.listdir("."))

if not os.path.exists(dicom_path):
    raise FileNotFoundError(f"Could not find: {dicom_path}")
else:
    print("Found DICOM:", dicom_path)
# Out:
# Current working dir: /workspaces/DICOM-reader-for-Copilot
# Top-level files: ['.git', 'dicom_to_json.ipynb', 'DCMTPS_Calculated(VC04 RESIDENT).json', '.DICOMtoJSON', 'DCMTPS_Calculated(VC04 RESIDENT).dcm', 'README.md', 'requirement.txt', 'DCMRT_Plan(VC04 RESIDENT).dcm']
# Found DICOM: /workspaces/DICOM-reader-for-Copilot/DCMRT_Plan(VC04 RESIDENT).dcm

# %%
# Read and inspect the dataset (quick peek)

ds = pydicom.dcmread(dicom_path, stop_before_pixels=True)

# Show a quick peek of a few elements
for i, elem in enumerate(ds):
    if i >= 10:
        break
    print(f"{elem.tag} {elem.VR} {keyword_for_tag(elem.tag) or ''} = {str(elem.value)[:120]}")
# Out:
# (0008,0005) CS SpecificCharacterSet = ISO_IR 100
# (0008,0012) DA InstanceCreationDate = 20260219
# (0008,0013) TM InstanceCreationTime = 204134
# (0008,0016) UI SOPClassUID = 1.2.840.10008.5.1.4.1.1.481.5
# (0008,0018) UI SOPInstanceUID = 1.3.6.1.4.1.2452.6.2842543894.1313122320.560499639.637827553
# (0008,0020) DA StudyDate =
# (0008,0030) TM StudyTime =
# (0008,0050) SH AccessionNumber =
# (0008,0060) CS Modality = RTPLAN
# (0008,0070) LO Manufacturer = Nucletron

# %%
# Convert to JSON (full recursive metadata)

metadata = dataset_to_dict(ds)

json_path = os.path.splitext(dicom_path)[0] + ".json"
with open(json_path, "w", encoding="utf-8") as f:
    json.dump(metadata, f, indent=2, ensure_ascii=False)

print("Wrote:", json_path, "| Size:", os.path.getsize(json_path), "bytes")
# Out:
# Wrote: /workspaces/DICOM-reader-for-Copilot/DCMRT_Plan(VC04 RESIDENT).json | Size: 229763 bytes

# %%
# (Optional) Display a small slice inline to verify

def find_first(keyword_name: str):
    """Find the first element with a given keyword in the JSON structure."""
    for item in metadata:
        if item.get("keyword") == keyword_name:
            return item
    return None

for kw in ["FractionGroupSequence", "BeamSequence", "ControlPointSequence", "DoseReferenceSequence",
           "DoseUnits", "DoseType", "GridFrameOffsetVector", "PixelSpacing", "DoseGridScaling"]:
    hit = find_first(kw)
    if hit:
        print(f"=== Found {kw} ===")
        # Print a condensed view
        print(json.dumps(hit, indent=2)[:1500] + "\n...(truncated)...\n")
# Out:
# === Found FractionGroupSequence ===
# {
#   "tag": "(300A,0070)",
#   "keyword": "FractionGroupSequence",
#   "name": "Fraction Group Sequence",
#   "vr": "SQ",
#   "value": [
#     [
#       {
#         "tag": "(300A,0071)",
#         "keyword": "FractionGroupNumber",
#         "name": "Fraction Group Number",
#         "vr": "IS",
#         "value": "1"
#       },
#       {
#         "tag": "(300A,0078)",
#         "keyword": "NumberOfFractionsPlanned",
#         "name": "Number of Fractions Planned",
#         "vr": "IS",
#         "value": "5"
#       },
#       {
#         "tag": "(300A,0080)",
#         "keyword": "NumberOfBeams",
#         "name": "Number of Beams",
#         "vr": "IS",
#         "value": "0"
#       },
#       {
#         "tag": "(300A,00A0)",
#         "keyword": "NumberOfBrachyApplicationSetups",
#         "name": "Number of Brachy Application Setups",
#         "vr": "IS",
#         "value": "1"
#       },
#       {
#         "tag": "(300C,000A)",
#         "keyword": "ReferencedBrachyApplicationSetupSequence",
#         "name": "Referenced Brachy Application Setup Sequence",
#         "vr": "SQ",
#         "value": [
#           [
#             {
#               "tag": "(300A,00A4)",
#               "keyword": "BrachyApplicationSetupDose",
#               "name": "Brachy Application Setup Dose",
#               "vr": "DS",
#               "value": "6.00000000000000"
#             },
#             {
#               "tag": "(300C,000C)",
#               "keyword": "ReferencedBrachyApplicationSetupNumber",
#               "name": "Referenced Brachy Application Setup Number",
#
# ...(truncated)...
#
# === Found DoseReferenceSequence ===
# {
#   "tag": "(300A,0010)",
#   "keyword": "DoseReferenceSequence",
#   "name": "Dose Reference Sequence",
#   "vr": "SQ",
#   "value": [
#     [
#       {
#         "tag": "(300A,0012)",
#         "keyword": "DoseReferenceNumber",
#         "name": "Dose Reference Number",
#         "vr": "IS",
#         "value": "1"
#       },
#       {
#         "tag": "(300A,0014)",
#         "keyword": "DoseReferenceStructureType",
#         "name": "Dose Reference Structure Type",
#         "vr": "CS",
#         "value": "COORDINATES"
#       },
#       {
#         "tag": "(300A,0016)",
#         "keyword": "DoseReferenceDescription",
#         "name": "Dose Reference Description",
#         "vr": "LO",
#         "value": "-"
#       },
#       {
#         "tag": "(300A,0018)",
#         "keyword": "DoseReferencePointCoordinates",
#         "name": "Dose Reference Point Coordinates",
#         "vr": "DS",
#         "value": "[-31.148212, 106.340656, -587.126844]"
#       },
#       {
#         "tag": "(300A,0020)",
#         "keyword": "DoseReferenceType",
#         "name": "Dose Reference Type",
#         "vr": "CS",
#         "value": "UNSPECIFIED"
#       },
#       {
#         "tag": "(300A,0026)",
#         "keyword": "TargetPrescriptionDose",
#         "name": "Target Prescription Dose",
#         "vr": "DS",
#         "value": "5.973904"
#       }
#     ],
#     [
#       {
#         "tag": "(300A,0012)",
#         "keyword": "DoseReferenceNumber",
#         "name": "Dose Reference Number",
#         "vr": "IS",
#         "value": "2"
#       },
#       {
#         "tag": "(300A,0014)",
#
# ...(truncated)...

# %%
# Diagnostic: which names are defined in the kernel? 
# (this is an optinal code to diagnostic which names are available in the current kernel, to help with debugging if something is missing. You can ignore this part if you want.)
import builtins

print("Has dataset_to_dict? ", 'dataset_to_dict' in globals())
print("Has to_jsonable?    ", 'to_jsonable' in globals())
print("Has element_header? ", 'element_header' in globals())
print("Has ds?             ", 'ds' in globals())
# Out:
# Has dataset_to_dict?  True
# Has to_jsonable?     False
# Has element_header?  True
# Has ds?              True
